# %%
import pandas as pd

# %%
#read the csv file
df_exams = pd.read_csv('/Users/omeryildiz/Downloads/StudentsPerformance.csv')

# %%
#showing the dataframe
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %% [markdown]
# # Attributes

# %%
# getting access to the shape attribute
df_exams.shape
# Out:
# (1000, 8)

# %%
# getting access to the index attribute
df_exams.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
# getting access to the columns attribute
df_exams.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
#datatypes of the columns
df_exams.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %%
#getting the first 5 columns
df_exams.head(5)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
#getting the information about the dataframe
df_exams.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
#describing the basic statistics of the dataframe
df_exams.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %% [markdown]
# # Functions

# %%
len(df_exams)
# Out:
# 1000

# %%
max(df_exams)
# Out:
# 'writing score'

# %%
max(df_exams.index)
# Out:
# 999

# %%
min(df_exams.index)
# Out:
# 0

# %%
type(df_exams)
# Out:
# pandas.core.frame.DataFrame

# %%
round(df_exams, 2)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %% [markdown]
# # Selecting a Column

# %%
df_exams['gender']
# Out:
# 0      female
# 1      female
# 2      female
# 3        male
# 4        male
#         ...
# 995    female
# 996      male
# 997    female
# 998    female
# 999    female
# Name: gender, Length: 1000, dtype: object

# %%
df_exams.gender
# Out:
# 0      female
# 1      female
# 2      female
# 3        male
# 4        male
#         ...
# 995    female
# 996      male
# 997    female
# 998    female
# 999    female
# Name: gender, Length: 1000, dtype: object

# %%
#df_exams.math score -- this woould cause an error because python syntax does not accept space between the words. Instead of this one, use the below one 

df_exams['math score']
# Out:
# 0      72
# 1      69
# 2      90
# 3      47
# 4      76
#        ..
# 995    88
# 996    62
# 997    59
# 998    68
# 999    77
# Name: math score, Length: 1000, dtype: int64

# %% [markdown]
# # Selecting more columns

# %%
df_exams.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df_exams[['gender','math score']]
# Out:
#      gender  math score
# 0    female          72
# 1    female          69
# 2    female          90
# 3      male          47
# 4      male          76
# ..      ...         ...
# 995  female          88
# 996    male          62
# 997  female          59
# 998  female          68
# 999  female          77
#
# [1000 rows x 2 columns]

# %%
df_exams[['gender','writing score','reading score', 'math score']]
# Out:
#      gender  writing score  reading score  math score
# 0    female             74             72          72
# 1    female             88             90          69
# 2    female             93             95          90
# 3      male             44             57          47
# 4      male             75             78          76
# ..      ...            ...            ...         ...
# 995  female             95             99          88
# 996    male             55             55          62
# 997  female             65             71          59
# 998  female             77             78          68
# 999  female             86             86          77
#
# [1000 rows x 4 columns]

# %% [markdown]
# # Create a New Column

# %%
df_exams['language score'] = 70 
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %% [markdown]
# # Creating a Column with an Array

# %%
import numpy as np

# %%
language_score = np.arange(0, 1000)

# %%
len(language_score)
# Out:
# 1000

# %%
df_exams['language score'] = language_score

# %%
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
#creating random integers

language_score_int=np.random.randint(0,100, size=1000)

# %%
df_exams['language score'] = language_score_int
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
#creating random floats

language_score_flo = np.random.uniform(1, 100, size=1000).round(0)

# %%
df_exams['language score'] = language_score_flo
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %% [markdown]
# # Operations in Dataframes

# %% [markdown]
# ## Operations in columns

# %%
df_exams = pd.read_csv('/Users/omeryildiz/Downloads/StudentsPerformance.csv')
df_exams.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
# calculate the sum of a column
df_exams['math score'].sum()
# Out:
# 66089

# %%
# count, mean, std, min, max
df_exams['math score'].mean()
# Out:
# 66.089

# %%
df_exams['math score'].std()
# Out:
# 15.16308009600945

# %%
df_exams['math score'].min()
# Out:
# 0

# %%
df_exams['math score'].max()
# Out:
# 100

# %%
df_exams['math score'].count()
# Out:
# 1000

# %%
df_exams.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %% [markdown]
# ## Operations in Rows

# %%
df_exams['math score']+df_exams['writing score']+df_exams['reading score']
# Out:
# 0      218
# 1      247
# 2      278
# 3      148
# 4      229
#       ...
# 995    282
# 996    172
# 997    195
# 998    223
# 999    249
# Length: 1000, dtype: int64

# %%
df_exams['average score'] = (df_exams['math score']+df_exams['writing score']+df_exams['reading score'])/3
df_exams.round(2)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
# counting gender elements

len(df_exams['gender'])

# count() method

df_exams['gender'].count()
# Out:
# 1000

# %%
# counting gender elements by category

df_exams['gender'].value_counts()
# Out:
# female    518
# male      482
# Name: gender, dtype: int64

# %%
# return the relative frequency

df_exams['gender'].value_counts(normalize=True)
# Out:
# female    0.518
# male      0.482
# Name: gender, dtype: float64

# %%
df_exams['parental level of education'].value_counts()
# Out:
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: parental level of education, dtype: int64

# %%
df_exams['parental level of education'].value_counts(normalize=True).round(2)
# Out:
# some college          0.23
# associate's degree    0.22
# high school           0.20
# some high school      0.18
# bachelor's degree     0.12
# master's degree       0.06
# Name: parental level of education, dtype: float64

# %% [markdown]
# # Sort a Dataframe

# %%
# sort by columns

df_exams.sort_values(by='math score')
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 59   female        group C            some high school  free/reduced
# 980  female        group B                 high school  free/reduced
# 17   female        group B            some high school  free/reduced
# 787  female        group B                some college      standard
# 145  female        group C                some college  free/reduced
# ..      ...            ...                         ...           ...
# 625    male        group D                some college      standard
# 623    male        group A                some college      standard
# 451  female        group E                some college      standard
# 962  female        group E          associate's degree      standard
# 149    male        group E          associate's degree  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
# sort descending by columns

df_exams.sort_values(by='math score', ascending=False)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 962  female        group E          associate's degree      standard
# 625    male        group D                some college      standard
# 458  female        group E           bachelor's degree      standard
# 623    male        group A                some college      standard
# 451  female        group E                some college      standard
# ..      ...            ...                         ...           ...
# 145  female        group C                some college  free/reduced
# 787  female        group B                some college      standard
# 17   female        group B            some high school  free/reduced
# 980  female        group B                 high school  free/reduced
# 59   female        group C            some high school  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
# sort by multiple columns
df_exams.sort_values(by=['math score', 'reading score'], ascending=False)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 149    male        group E          associate's degree  free/reduced
# 458  female        group E           bachelor's degree      standard
# 916    male        group E           bachelor's degree      standard
# 962  female        group E          associate's degree      standard
# 625    male        group D                some college      standard
# ..      ...            ...                         ...           ...
# 145  female        group C                some college  free/reduced
# 787  female        group B                some college      standard
# 17   female        group B            some high school  free/reduced
# 980  female        group B                 high school  free/reduced
# 59   female        group C            some high school  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
#  sort descending by multiple columns and update the dataframe
df_exams.sort_values(by=['math score', 'reading score'], ascending=False, inplace=True)

# %%
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 149    male        group E          associate's degree  free/reduced
# 458  female        group E           bachelor's degree      standard
# 916    male        group E           bachelor's degree      standard
# 962  female        group E          associate's degree      standard
# 625    male        group D                some college      standard
# ..      ...            ...                         ...           ...
# 145  female        group C                some college  free/reduced
# 787  female        group B                some college      standard
# 17   female        group B            some high school  free/reduced
# 980  female        group B                 high school  free/reduced
# 59   female        group C            some high school  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
# sort descending with a key function
df_exams.sort_values('race/ethnicity', ascending=True, key=lambda x:x.str.lower())
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 741  female        group A          associate's degree  free/reduced
# 151    male        group A           bachelor's degree      standard
# 811    male        group A                 high school  free/reduced
# 112    male        group A          associate's degree      standard
# 25     male        group A             master's degree  free/reduced
# ..      ...            ...                         ...           ...
# 751    male        group E                some college      standard
# 915  female        group E                some college      standard
# 592    male        group E           bachelor's degree      standard
# 479    male        group E          associate's degree      standard
# 517  female        group E                some college      standard
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %% [markdown]
# # Pivot()

# %%
import pandas as pd

# %%
"""if you have the utf error when running out the code without encoding, you may have the error. 
 please put: encoding= "ISO-8859-1" after comma"""

df_gdp = pd.read_csv('gdp.csv', encoding="ISO-8859-1")
df_gdp
# Out:
#       unid wbid      country  year        SES       gdppc  yrseduc  popshare
# 0        4  AFG  Afghanistan  1970   3.474212   709.00000      NaN  0.003097
# 1        4  AFG  Afghanistan  1920  26.968016   731.75677      NaN  0.003245
# 2        4  AFG  Afghanistan  1990   1.269530   604.00000      NaN  0.002347
# 3        4  AFG  Afghanistan  1960  15.763076   739.00000      NaN  0.003039
# 4        4  AFG  Afghanistan  2000   2.061114   565.00000      NaN  0.003309
# ...    ...  ...          ...   ...        ...         ...      ...       ...
# 2081   716  ZWE     Zimbabwe  1940  52.746567   813.00000      NaN  0.001113
# 2082   716  ZWE     Zimbabwe  2010  27.091389  1388.97300      NaN  0.002074
# 2083   716  ZWE     Zimbabwe  1990  59.110970  2526.07230      NaN  0.002039
# 2084   716  ZWE     Zimbabwe  1900  54.722645   601.00000      NaN  0.000996
# 2085   716  ZWE     Zimbabwe  1960  53.811077   938.00000      NaN  0.001268
#
# [2086 rows x 8 columns]

# %%
df_gdp.pivot(index="year", columns="country", values="gdppc")
# Out:
# country  Afghanistan     Albania      Algeria      Angola  Argentina  \
# year
# 1880       585.46509   522.00000    819.18604   533.66669   1731.500
# 1890       635.93024   598.00000    923.37207   567.33331   2152.000
# 1900       686.39532   685.00000   1027.55810   601.00000   2756.000
# 1910       736.86047   780.00000   1131.74410   628.69232   3822.000
# 1920       731.75677   861.31250   1201.21620   682.62964   3473.000
# 1930       702.83783   929.57141   1255.81080   747.81482   4080.000
# 1940       673.91895   965.28571   1310.40540   813.00000   4161.000
# 1950       645.00000  1001.00000   1365.00000  1052.00000   4987.000
# 1960       739.00000  1451.00000   2088.00000  1253.00000   5559.000
# 1970       709.00000  2004.00000   2249.00000  1768.00000   7302.000
# 1980       690.00000  2347.00000   3152.00000   961.00000   8206.000
# 1990       604.00000  4557.40820  10238.88400  4806.43020  10833.503
# ...

# %% [markdown]
# # pivot_table()

# %%
df_sales = pd.read_excel("supermarket_sales.xlsx")
df_sales
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
df_sales.pivot_table(index="Gender", aggfunc="sum")
# Out:
#         Quantity  Rating    Tax 5%       Total  Unit price       cogs  \
# Gender
# Female      2869  3489.2  7994.425  167882.925    27687.24  159888.50
# Male        2641  3483.5  7384.944  155083.824    27984.89  147698.88
#
#         gross income  gross margin percentage
# Gender
# Female      7994.425              2385.714286
# Male        7384.944              2376.190476

# %%
df_sales.pivot_table(index="Gender", values=["Quantity", "Total"], aggfunc="sum")
# Out:
#         Quantity       Total
# Gender
# Female      2869  167882.925
# Male        2641  155083.824

# %%
df_sales.pivot_table(index="Gender", columns="Product line", values="Total", aggfunc="sum")
# Out:
# Product line  Electronic accessories  Fashion accessories  Food and beverages  \
# Gender
# Female                    27102.0225            30437.400          33170.9175
# Male                      27235.5090            23868.495          22973.9265
#
# Product line  Health and beauty  Home and lifestyle  Sports and travel
# Gender
# Female               18560.9865          30036.8775         28574.7210
# Male                 30632.7525          23825.0355         26548.1055

# %%
import pandas as pd

# %%
df_population_raw_data = pd.read_csv('population_total.csv')

# %%
df_population_raw_data
# Out:
#             country    year    population
# 0             China  2020.0  1.439324e+09
# 1             China  2019.0  1.433784e+09
# 2             China  2018.0  1.427648e+09
# 3             China  2017.0  1.421022e+09
# 4             China  2016.0  1.414049e+09
# ...             ...     ...           ...
# 4180  United States  1965.0  1.997337e+08
# 4181  United States  1960.0  1.867206e+08
# 4182  United States  1955.0  1.716853e+08
# 4183          India  1960.0  4.505477e+08
# 4184          India  1955.0  4.098806e+08
#
# [4185 rows x 3 columns]

# %%
df_population_raw_data.dropna(inplace=True) #drop the rows with missing values and update the dataframe with 'inplace'

# %%
df_pivot = df_population_raw_data.pivot(index="year", columns="country", values="population")

# %%
df_selected_countries = df_pivot[['United States', 'United Kingdom', 'Japan','Turkey']]

# %%
df_selected_countries
# Out:
# country  United States  United Kingdom        Japan      Turkey
# year
# 1955.0     171685336.0      51063902.0   89018257.0  24270600.0
# 1960.0     186720571.0      52370602.0   93673615.0  27472345.0
# 1965.0     199733676.0      54240850.0   98447002.0  30972994.0
# 1970.0     209513341.0      55573453.0  104929251.0  34876303.0
# 1975.0     219081251.0      56152333.0  112413359.0  39277258.0
# 1980.0     229476354.0      56209171.0  117816940.0  43975971.0
# 1985.0     240499825.0      56413553.0  121883482.0  49133937.0
# 1990.0     252120309.0      57134391.0  124505240.0  53921760.0
# 1995.0     265163745.0      57932453.0  126365484.0  58486456.0
# 2000.0     281710909.0      58923309.0  127524174.0  63240194.0
# 2005.0     294993511.0      60287954.0  128326116.0  67903469.0
# 2010.0     309011475.0      63459808.0  128542353.0  72326988.0
# 2015.0     320878310.0      65860146.0  127985133.0  78529409.0
# 2016.0     323015995.0      66297944.0  127763265.0  79827871.0
# ...

# %% [markdown]
# # Lineplot

# %%
df_selected_countries.plot(kind='line', xlabel='Year', ylabel='Population', title='Population (1955-2020)', figsize=(10,5))
# Out:
# <AxesSubplot:title={'center':'Population (1955-2020)'}, xlabel='Year', ylabel='Population'>

# %%
# export the dataframe with the selected countries as an excel file
 
df_selected_countries.to_excel('population_total_selected_countries.xlsx')

# %% [markdown]
# # Barplot

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## Single Barplot

# %%
df_selected_countries_2020 = df_selected_countries[df_selected_countries.index.isin([2020])]

# %%
df_selected_countries_2020 = df_selected_countries_2020.T

# %%
#transpose the dataframe
df_selected_countries_2020 = df_selected_countries_2020.T

# %%
df_selected_countries_2020.plot(kind='bar', color='orange', xlabel='Country', ylabel='Population', title='Population (2020)', figsize=(10,5))
# Out:
# <AxesSubplot:title={'center':'Population (2020)'}, xlabel='Country', ylabel='Population'>

# %%
df_pivot_sample = df_selected_countries[df_selected_countries.index.isin([1980,1990,2000,2010,2020])]

# %%
df_pivot_sample
# Out:
# country  United States  United Kingdom        Japan      Turkey
# year
# 1980.0     229476354.0      56209171.0  117816940.0  43975971.0
# 1990.0     252120309.0      57134391.0  124505240.0  53921760.0
# 2000.0     281710909.0      58923309.0  127524174.0  63240194.0
# 2010.0     309011475.0      63459808.0  128542353.0  72326988.0
# 2020.0     331002651.0      67886011.0  126476461.0  84339067.0

# %%
df_pivot_sample.plot(kind='bar', figsize=(10,5))

plt.show() #to show the plot

# %% [markdown]
# # Pie Chart

# %%
df_selected_countries_2020
# Out:
# year                 2020.0
# country
# United States   331002651.0
# United Kingdom   67886011.0
# Japan           126476461.0
# Turkey           84339067.0

# %%
df_selected_countries_2020.rename(columns={2020:'2020'}, inplace=True)

# %%
df_selected_countries_2020
# Out:
# year                   2020
# country
# United States   331002651.0
# United Kingdom   67886011.0
# Japan           126476461.0
# Turkey           84339067.0

# %%
df_selected_countries_2020.plot(kind='pie', y='2020', title='Population in 2020(%)', figsize=(10,5))

plt.savefig('population_2020.png') #save the figure

plt.show()
